# %% [markdown]
# <a href="https://colab.research.google.com/github/kiran162005/flyrank-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kiran162005/flyrank-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/kiran162005/flyrank-ml.git
# Out:
# Cloning into 'flyrank-ml'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 136 (delta 47), reused 99 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (136/136), 1.84 MiB | 8.39 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
# %cd flyrank-ml
# Out:
# /content/flyrank-ml/flyrank-ml

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# # My Lane as an ML Task
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# **ML Task Type:** Classification and Ranking
#
# The goal is to identify webpages that are likely to require a content refresh. The model predicts the likelihood that a webpage is declining, and pages are ranked by this likelihood so the content team can review the highest-priority pages first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# # Target or Proxy
#
# For the starter dataset, I will use the proxy target:
#
# **is_declining_label = (trend_direction == "down")**
#
# This proxy is derived from the observed `trend_direction` column using the rule `trend_direction == "down"`. It is a proxy label based on the current data, not a future outcome. In the full warehouse dataset, a stronger target could predict future decline using historical data.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# # Success Metric
#
# The primary success metric is **Precision@50**.
#
# This metric measures how many of the top 50 recommended pages are actually declining.
#
# A higher Precision@50 means the content team spends more time reviewing pages that truly need attention, improving the efficiency of the review process.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)
print("\nUnit of Analysis: One row represents one webpage.\n")

display(df.head())

print("\nSelected Columns")

display(df[
    [
        "content_id",
        "client_id",
        "impressions_90d",
        "content_age_days",
        "days_since_last_update",
        "trend_direction",
    ]
].head())

# Create proxy target
df["is_declining_label"] = (
    df["trend_direction"] == "down"
).astype(int)

print("\nTarget Preview")

display(
    df[
        [
            "content_id",
            "trend_direction",
            "is_declining_label",
        ]
    ].head()
)
# Out:
# Dataset Shape: (30000, 44)
#
# Unit of Analysis: One row represents one webpage.
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# # Why ML Beats a Fixed Rule
#
# A fixed rule uses manually chosen thresholds and cannot capture complex relationships between multiple features.
#
# Machine learning can learn patterns from historical data by combining signals such as impressions, content age, CTR, average position, and engagement rate.
#
# The starter notebooks showed that a learned model achieved much higher Precision@50 than the baseline rule, making machine learning more effective for prioritizing pages while still supporting human decision-making.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
